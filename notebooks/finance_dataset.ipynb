# %%
pip install yfinance pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd

def fetch_extended_data(ticker: str, country: str, period='2500d'):
    df = yf.download(ticker, period=period)
    
    if df.empty:
        print(f"❌ No data fetched for {country} ({ticker})")
        return None
    
    filename = f"{country}_{ticker.replace('^','')}_extended.csv"
    df.to_csv(filename)
    print(f"{len(df)} rows saved to {filename}")
    return df

# Fetch data for all 3 countries
if __name__ == "__main__":
    tickers = {
        "^NSEI": "India",
        "^ISEQ": "Ireland",
        "^GSPC": "USA"
    }

    dfs = {}
    for ticker, country in tickers.items():
        dfs[country] = fetch_extended_data(ticker, country)
# Out:
# /var/folders/x6/m7520qdd4m1dts_g2lwmd0vc0000gn/T/ipykernel_8860/3926207484.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period=period)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/x6/m7520qdd4m1dts_g2lwmd0vc0000gn/T/ipykernel_8860/3926207484.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period=period)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/x6/m7520qdd4m1dts_g2lwmd0vc0000gn/T/ipykernel_8860/3926207484.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period=period)
# 2493 rows saved to India_NSEI_extended.csv
# 2499 rows saved to Ireland_ISEQ_extended.csv
# [*********************100%***********************]  1 of 1 completed
# 2500 rows saved to USA_GSPC_extended.csv

# %%
import pandas as pd

# %%
IND = pd.read_csv("/Users/rishabhsaudagar/Desktop/NCI CLG/SEMESTER 3/Thesis/Thesis_Dev/data/raw/India_NSEI_extended.csv")

IRE = pd.read_csv("/Users/rishabhsaudagar/Desktop/NCI CLG/SEMESTER 3/Thesis/Thesis_Dev/data/raw/Ireland_ISEQ_extended.csv")

USA = pd.read_csv("/Users/rishabhsaudagar/Desktop/NCI CLG/SEMESTER 3/Thesis/Thesis_Dev/data/raw/USA_GSPC_extended.csv")

# %%
print("IND",len(IND))
print("IRE",len(IRE))
print("USA",len(USA))
# Out:
# IND 2495
# IRE 2501
# USA 2502

# %%
IND.head(10)
# Out:
#         Price            Close             High              Low  \
# 0      Ticker            ^NSEI            ^NSEI            ^NSEI
# 1        Date              NaN              NaN              NaN
# 2  2015-05-20          8423.25   8440.349609375  8391.4501953125
# 3  2015-05-21           8421.0   8446.349609375           8382.5
# 4  2015-05-22  8458.9501953125  8489.5498046875   8420.599609375
# 5  2015-05-25          8370.25  8441.9501953125   8364.150390625
# 6  2015-05-26   8339.349609375   8378.900390625  8320.0498046875
# 7  2015-05-27   8334.599609375   8342.849609375  8277.9501953125
# 8  2015-05-28           8319.0           8364.5   8270.150390625
# 9  2015-05-29   8433.650390625   8443.900390625  8305.7001953125
#
#               Open  Volume
# 0            ^NSEI   ^NSEI
# 1              NaN     NaN
# 2   8392.650390625  123600
# 3           8434.5  143800
# 4           8432.5  187300
# 5   8438.150390625  121300
# 6   8377.099609375  116800
# ...

# %%
IRE.head(10)
# Out:
#         Price             Close              High               Low  \
# 0      Ticker             ^ISEQ             ^ISEQ             ^ISEQ
# 1        Date               NaN               NaN               NaN
# 2  2015-09-01  6260.35009765625  6405.97021484375  6203.56982421875
# 3  2015-09-02     6272.66015625  6297.31005859375  6244.77978515625
# 4  2015-09-03    6388.919921875    6388.919921875  6269.43017578125
# 5  2015-09-04  6314.56982421875    6388.919921875  6314.56982421875
# 6  2015-09-07  6355.43994140625  6355.43994140625  6311.97021484375
# 7  2015-09-08  6406.56005859375  6445.43994140625  6355.43994140625
# 8  2015-09-09  6530.06005859375  6620.47021484375  6482.22021484375
# 9  2015-09-10    6494.759765625    6536.669921875   6435.6201171875
#
#                Open     Volume
# 0             ^ISEQ      ^ISEQ
# 1               NaN        NaN
# 2  6405.97021484375   46131900
# 3  6260.35009765625   48728700
# 4  6269.43017578125   47569500
# ...

# %%
USA.head()
# Out:
#         Price              Close               High                Low  \
# 0      Ticker              ^GSPC              ^GSPC              ^GSPC
# 1        Date                NaN                NaN                NaN
# 2  2015-07-23   2102.14990234375    2116.8701171875    2098.6298828125
# 3  2015-07-24   2079.64990234375  2106.010009765625  2077.090087890625
# 4  2015-07-27  2067.639892578125   2078.18994140625   2063.52001953125
#
#                 Open      Volume
# 0              ^GSPC       ^GSPC
# 1                NaN         NaN
# 2  2114.159912109375  3772810000
# 3  2102.239990234375  3870040000
# 4   2078.18994140625  3836750000

# %%
print("IND:" ,len(IND))
print("IRE",len(IRE))
print("USA",len(USA))
# Out:
# IND: 2495
# IRE 2501
# USA 2502

# %%
for name, df in [('India', IND), ('Ireland', IRE), ('USA', USA)]:
    print(f"--- {name} ---")
    print(df.head())
    print(df.info())
    print(df.describe())
    print("\n\n")
# Out:
# --- India ---
#         Price            Close             High              Low  \
# 0      Ticker            ^NSEI            ^NSEI            ^NSEI
# 1        Date              NaN              NaN              NaN
# 2  2015-05-20          8423.25   8440.349609375  8391.4501953125
# 3  2015-05-21           8421.0   8446.349609375           8382.5
# 4  2015-05-22  8458.9501953125  8489.5498046875   8420.599609375
#
#              Open  Volume
# 0           ^NSEI   ^NSEI
# 1             NaN     NaN
# 2  8392.650390625  123600
# 3          8434.5  143800
# 4          8432.5  187300
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2495 entries, 0 to 2494
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   2495 non-null   object
#  1   Close   2494 non-null   object
#  2   High    2494 non-null   object
#  3   Low     2494 non-null   object
#  4   Open    2494 non-null   object
# ...

# %%
import pandas as pd


IND = pd.read_csv('India_NSEI_1497rows.csv', skiprows=[0, 1])
IRE = pd.read_csv('Ireland_ISEQ_1500rows.csv', skiprows=[0, 1])
USA = pd.read_csv('USA_GSPC_1500rows.csv', skiprows=[0, 1])

# %%
print(IND.columns)
print(IRE.columns)
print(USA.columns)
# Out:
# Index(['Date', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')
# Index(['Date', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')
# Index(['Date', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
column_names = ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']

# %%
for df in [IND, IRE, USA]:
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)

# %%
print(IND.head())
print(IND.info())
# Out:
#               Unnamed: 1    Unnamed: 2    Unnamed: 3    Unnamed: 4  \
# Date
# 2019-06-03  12088.549805  12088.549805  12103.049805  11920.099609
# 2019-06-04  12021.650391  12021.650391  12095.200195  12005.849609
# 2019-06-06  11843.750000  11843.750000  12039.799805  11830.250000
# 2019-06-07  11870.650391  11870.650391  11897.500000  11769.500000
# 2019-06-10  11922.700195  11922.700195  11975.049805  11871.750000
#
#               Unnamed: 5  Unnamed: 6
# Date
# 2019-06-03  11953.750000      315300
# 2019-06-04  12052.650391      289200
# 2019-06-06  12039.799805      415200
# 2019-06-07  11865.200195      302500
# 2019-06-10  11934.900391      303300
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1497 entries, 2019-06-03 to 2025-06-25
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 1  1497 non-null   float64
#  1   Unnamed: 2  1497 non-null   float64
# ...

# %%
correct_columns = ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']

IND.columns = correct_columns
IRE.columns = correct_columns
USA.columns = correct_columns

# %%
print(IND.head())
print(IND.index.name)  
print(IND.columns)
# Out:
#                Adj Close         Close          High           Low  \
# Date
# 2019-06-03  12088.549805  12088.549805  12103.049805  11920.099609
# 2019-06-04  12021.650391  12021.650391  12095.200195  12005.849609
# 2019-06-06  11843.750000  11843.750000  12039.799805  11830.250000
# 2019-06-07  11870.650391  11870.650391  11897.500000  11769.500000
# 2019-06-10  11922.700195  11922.700195  11975.049805  11871.750000
#
#                     Open  Volume
# Date
# 2019-06-03  11953.750000  315300
# 2019-06-04  12052.650391  289200
# 2019-06-06  12039.799805  415200
# 2019-06-07  11865.200195  302500
# 2019-06-10  11934.900391  303300
# Date
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
import matplotlib.pyplot as plt
import numpy as np


markets = {
    'India (NSEI)': IND,
    'Ireland (ISEQ)': IRE,
    'USA (S&P 500)': USA
}

for name, df in markets.items():
    print(f"\n EDA for {name}")
    
    
    df['LogRet'] = np.log(df['Close'] / df['Close'].shift(1))
    
    
    plt.figure(figsize=(12, 4))
    df['Close'].plot(title=f"{name} - Closing Prices")
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.grid(True)
    plt.show()
    
    
    plt.figure(figsize=(12, 4))
    df['LogRet'].plot(title=f"{name} - Daily Log Returns")
    plt.xlabel("Date")
    plt.ylabel("Log Return")
    plt.grid(True)
    plt.show()
    
    
    plt.figure(figsize=(10, 4))
    df['LogRet'].hist(bins=50, density=True)
    plt.title(f"{name} - Log Returns Distribution")
    plt.xlabel("Log Return")
    plt.grid(True)
    plt.show()
    
    
    vol = df['LogRet'].std() * np.sqrt(252)
    print(f"Annualized Volatility for {name}: {vol:.4f}")
# Out:
#  EDA for India (NSEI)
# Annualized Volatility for India (NSEI): 0.1857
#
#  EDA for Ireland (ISEQ)
# Annualized Volatility for Ireland (ISEQ): 0.2167
#
#  EDA for USA (S&P 500)
# Annualized Volatility for USA (S&P 500): 0.2111

# %% [markdown]
# ### Moving Average

# %%
def add_technical_indicators(df):
    df = df.copy()

    # Moving Averages
    df['MA_5'] = df['Close'].rolling(window=5).mean()
    df['MA_20'] = df['Close'].rolling(window=20).mean()
    
    # Rolling Volatility
    df['Vol_10'] = df['LogRet'].rolling(window=10).std()
    
    # RSI (Relative Strength Index)
    delta = df['Close'].diff()
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    
    avg_gain = gain.rolling(window=14).mean()
    avg_loss = loss.rolling(window=14).mean()
    
    rs = avg_gain / avg_loss
    df['RSI_14'] = 100 - (100 / (1 + rs))

    # MACD and Signal Line
    ema_12 = df['Close'].ewm(span=12, adjust=False).mean()
    ema_26 = df['Close'].ewm(span=26, adjust=False).mean()
    df['MACD'] = ema_12 - ema_26
    df['Signal'] = df['MACD'].ewm(span=9, adjust=False).mean()

    return df

# %%
IND = add_technical_indicators(IND)
IRE = add_technical_indicators(IRE)
USA = add_technical_indicators(USA)

# %%
print(IND[['MA_5', 'MA_20', 'Vol_10', 'RSI_14', 'MACD', 'Signal']].tail())
# Out:
#                     MA_5         MA_20    Vol_10     RSI_14        MACD  \
# Date
# 2025-06-19  24824.760156  24850.567383  0.006424  51.320591  108.930767
# 2025-06-20  24903.520313  24863.529883  0.006917  60.437225  121.311865
# 2025-06-23  24908.600391  24862.067383  0.007034  61.527515  118.421706
# 2025-06-24  24946.790234  24872.974902  0.007117  61.418763  120.587226
# 2025-06-25  25033.330078  24897.589941  0.007572  62.814274  136.896002
#
#                 Signal
# Date
# 2025-06-19  154.363158
# 2025-06-20  147.752899
# 2025-06-23  141.886660
# 2025-06-24  137.626774
# 2025-06-25  137.480619

# %%
features = ['Close', 'MA_5', 'MA_20', 'Vol_10', 'RSI_14', 'MACD', 'Signal']


IND.dropna(inplace=True)
IRE.dropna(inplace=True)
USA.dropna(inplace=True)


X_IND = IND[features].copy()
X_IRE = IRE[features].copy()
X_USA = USA[features].copy()


IND['Target'] = IND['Close'].shift(-1)
IRE['Target'] = IRE['Close'].shift(-1)
USA['Target'] = USA['Close'].shift(-1)


IND.dropna(inplace=True)
IRE.dropna(inplace=True)
USA.dropna(inplace=True)

# %%
IND.head()
# Out:
#                Adj Close         Close          High           Low  \
# Date
# 2019-07-01  11865.599609  11865.599609  11884.650391  11830.799805
# 2019-07-02  11910.299805  11910.299805  11917.450195  11814.700195
# 2019-07-03  11916.750000  11916.750000  11945.200195  11887.049805
# 2019-07-04  11946.750000  11946.750000  11969.250000  11923.650391
# 2019-07-05  11811.150391  11811.150391  11981.750000  11797.900391
#
#                     Open  Volume    LogRet          MA_5         MA_20  \
# Date
# 2019-07-01  11839.900391  278400  0.006489  11827.999805  11840.352490
# 2019-07-02  11890.299805  363200  0.003760  11850.769727  11831.439990
# 2019-07-03  11932.150391  340500  0.000541  11864.609766  11826.194971
# 2019-07-04  11928.799805  333600  0.002514  11885.649805  11831.344971
# 2019-07-05  11964.750000  530700 -0.011415  11890.109961  11828.369971
#
#               Vol_10     RSI_14       MACD     Signal        Target
# Date
# ...

# %%
IRE.head()
# Out:
#               Adj Close        Close         High          Low         Open  \
# Date
# 2019-08-30  5879.419922  5879.419922  5910.029785  5846.540039  5846.540039
# 2019-09-02  5909.560059  5909.560059  5931.750000  5883.899902  5883.899902
# 2019-09-03  5868.479980  5868.479980  5914.759766  5853.330078  5914.759766
# 2019-09-04  5962.189941  5962.189941  5971.589844  5868.560059  5868.560059
# 2019-09-05  6031.580078  6031.580078  6043.129883  5959.370117  5959.370117
#
#               Volume    LogRet         MA_5        MA_20    Vol_10     RSI_14  \
# Date
# 2019-08-30  26373000  0.005512  5811.755957  5800.227490  0.012740  52.220816
# 2019-09-02  17569800  0.005113  5845.000000  5805.228003  0.012671  53.413252
# 2019-09-03  27311900 -0.006976  5852.428027  5809.569995  0.010502  57.571183
# 2019-09-04  28303400  0.015842  5893.350000  5816.871484  0.010221  65.774198
# 2019-09-05  30499400  0.011571  5930.245996  5821.267993  0.010188  65.522867
#
# ...

# %%
USA.head()
# Out:
#               Adj Close        Close         High          Low         Open  \
# Date
# 2019-08-02  2932.050049  2932.050049  2945.500000  2914.110107  2943.899902
# 2019-08-05  2844.739990  2844.739990  2898.070068  2822.120117  2898.070068
# 2019-08-06  2881.770020  2881.770020  2884.399902  2847.419922  2861.179932
# 2019-08-07  2883.979980  2883.979980  2892.169922  2825.709961  2858.649902
# 2019-08-08  2938.090088  2938.090088  2938.719971  2894.469971  2896.209961
#
#                 Volume    LogRet         MA_5        MA_20    Vol_10  \
# Date
# 2019-08-02  3882810000 -0.007309  2980.027979  2993.827002  0.006666
# 2019-08-05  4542850000 -0.030230  2944.781982  2987.266504  0.011039
# 2019-08-06  4156640000  0.012933  2918.500000  2982.373511  0.011891
# 2019-08-07  4512720000  0.000767  2899.220020  2976.919006  0.011628
# 2019-08-08  4118530000  0.018588  2896.126025  2973.828015  0.013731
#
#                RSI_14       MACD     Signal       Target
# Date
# ...

# %%
# Make sure your DataFrames are named correctly
IND.to_csv("Cleaned_INDIA.csv")
IRE.to_csv("Cleaned_IRELAND.csv")
USA.to_csv("Cleaned_USA.csv")

print("All datasets exported successfully:")
print("- Cleaned_INDIA.csv")
print("- Cleaned_IRELAND.csv")
print("- Cleaned_USA.csv")
# Out:
# All datasets exported successfully:
# - Cleaned_INDIA.csv
# - Cleaned_IRELAND.csv
# - Cleaned_USA.csv

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Select relevant columns
features = ['Close', 'MA_5', 'MA_20', 'Vol_10', 'RSI_14', 'MACD', 'Signal']
IND_clean = IND.dropna()[features + ['Target']]  # ensure no NaNs

# Scale features
scaler_ind = MinMaxScaler()
X_scaled_ind = scaler_ind.fit_transform(IND_clean[features])
y_ind = IND_clean['Target'].values

# %%
def create_windows(X, y, window_size=60):
    Xs, ys = [], []
    for i in range(len(X) - window_size):
        Xs.append(X[i:i+window_size])
        ys.append(y[i+window_size])
    return np.array(Xs), np.array(ys)

X_tensor_ind, y_tensor_ind = create_windows(X_scaled_ind, y_ind)

# %%
def split_data(X, y, train_ratio=0.8):
    split = int(train_ratio * len(X))
    return X[:split], X[split:], y[:split], y[split:]

X_train_ind, X_test_ind, y_train_ind, y_test_ind = split_data(X_tensor_ind, y_tensor_ind)

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
def build_cnn_lstm_model(input_shape):
    model = Sequential()
    
    # CNN block
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))
    
    # LSTM block
    model.add(LSTM(units=64, activation='tanh'))
    model.add(Dropout(0.2))
    
    # Output
    model.add(Dense(1))  # regression: next-day close
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# %%
# Use your prepared tensors from earlier
# X_train_ind, X_test_ind, y_train_ind, y_test_ind

input_shape = X_train_ind.shape[1:]  # (60, 7)
model = build_cnn_lstm_model(input_shape)

# Early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train_ind, y_train_ind,
    validation_data=(X_test_ind, y_test_ind),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 1s 11ms/step - loss: 269409664.0000 - mae: 16040.5244 - val_loss: 576511616.0000 - val_mae: 23992.0410
# Epoch 2/100
# 36/36 [==============================] - 0s 6ms/step - loss: 269169152.0000 - mae: 16033.0049 - val_loss: 576307136.0000 - val_mae: 23987.7773
# Epoch 3/100
# 36/36 [==============================] - 0s 6ms/step - loss: 269063008.0000 - mae: 16029.6738 - val_loss: 576172544.0000 - val_mae: 23984.9727
# Epoch 4/100
# 36/36 [==============================] - 0s 6ms/step - loss: 268975840.0000 - mae: 16026.9619 - val_loss: 576047424.0000 - val_mae: 23982.3613
# Epoch 5/100
# 36/36 [==============================] - 0s 6ms/step - loss: 268893472.0000 - mae: 16024.3809 - val_loss: 575926528.0000 - val_mae: 23979.8418
# Epoch 6/100
# 36/36 [==============================] - 0s 6ms/step - loss: 268809728.0000 - mae: 16021.7812 - val_loss: 575801472.0000 - val_mae: 23977.2344
# Epoch 7/100
# ...

# %%
# Predict on test set
y_pred_ind = model.predict(X_test_ind)

# Evaluation metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error

rmse = np.sqrt(mean_squared_error(y_test_ind, y_pred_ind))
mae = mean_absolute_error(y_test_ind, y_pred_ind)

print(f"Test RMSE: {rmse:.2f}")
print(f"Test MAE: {mae:.2f}")
# Out:
# 9/9 [==============================] - 0s 1ms/step
# Test RMSE: 23775.92
# Test MAE: 23757.12

# %%
from sklearn.preprocessing import MinMaxScaler

target_scaler = MinMaxScaler()
y_scaled = target_scaler.fit_transform(y_ind.reshape(-1, 1))

# %%
X_tensor_ind, y_tensor_ind = create_windows(X_scaled_ind, y_scaled.flatten())
X_train_ind, X_test_ind, y_train_ind, y_test_ind = split_data(X_tensor_ind, y_tensor_ind)

# %%
# Use your prepared tensors from earlier
# X_train_ind, X_test_ind, y_train_ind, y_test_ind

input_shape = X_train_ind.shape[1:]  # (60, 7)
model = build_cnn_lstm_model(input_shape)

# Early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train_ind, y_train_ind,
    validation_data=(X_test_ind, y_test_ind),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 1s 10ms/step - loss: 0.0411 - mae: 0.1487 - val_loss: 0.0137 - val_mae: 0.1126
# Epoch 2/100
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0040 - mae: 0.0492 - val_loss: 0.0022 - val_mae: 0.0398
# Epoch 3/100
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0026 - mae: 0.0400 - val_loss: 0.0035 - val_mae: 0.0525
# Epoch 4/100
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0023 - mae: 0.0371 - val_loss: 9.7853e-04 - val_mae: 0.0252
# Epoch 5/100
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0023 - mae: 0.0363 - val_loss: 0.0022 - val_mae: 0.0403
# Epoch 6/100
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0019 - mae: 0.0339 - val_loss: 0.0015 - val_mae: 0.0323
# Epoch 7/100
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0020 - mae: 0.0341 - val_loss: 8.5083e-04 - val_mae: 0.0235
# Epoch 8/100
# ...

# %%
y_pred_scaled = model.predict(X_test_ind)
y_pred = target_scaler.inverse_transform(y_pred_scaled)
y_true = target_scaler.inverse_transform(y_test_ind.reshape(-1, 1))
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
# Predict on test set
y_pred_ind = model.predict(X_test_ind)

# Evaluation metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error

rmse = np.sqrt(mean_squared_error(y_test_ind, y_pred_ind))
mae = mean_absolute_error(y_test_ind, y_pred_ind)

print(f"Test RMSE: {rmse:.2f}")
print(f"Test MAE: {mae:.2f}")
# Out:
# 9/9 [==============================] - 0s 2ms/step
# Test RMSE: 0.03
# Test MAE: 0.02
